# %% [markdown]
# <a href="https://colab.research.google.com/github/mythien107/busad878/blob/main/Week3_LabReport.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================
# Setup and Imports
# ============================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# Set plot style
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette("husl")

print("Libraries imported successfully!")

# %%
# ============================================
# Load Data
# ============================================

# Option A: Upload file manually
from google.colab import files
uploaded = files.upload()  # Click "Choose Files" and select manufacturing_quality.csv

# Load the data
df = pd.read_csv('manufacturing_quality.csv')
print(f"Data loaded: {len(df):,} rows, {len(df.columns)} columns")

# Option B: Import from the course's GitHub
url = "https://raw.githubusercontent.com/mythien107/busad878/refs/heads/main/manufacturing_quality.csv"
df = pd.read_csv(url)

# %%
# ============================================
# Quick Data Overview
# ============================================

print("=" * 50)
print("DATA OVERVIEW")
print("=" * 50)
print(f"\nShape: {df.shape}")
print(f"\nColumn types:\n{df.dtypes}")
print(f"\nMissing values:\n{df.isnull().sum()}")
print(f"\nFirst few rows:")
df.head()

# %%
# ============================================
# Summary Statistics
# ============================================

print("=" * 50)
print("SUMMARY STATISTICS")
print("=" * 50)
df.describe()

# %%
# ============================================
# Defect Analysis
# ============================================

print("=" * 50)
print("DEFECT ANALYSIS")
print("=" * 50)

# Total defects
print(f"\nTotal defects: {df['defect_count'].sum():,}")
print(f"Average defects per batch: {df['defect_count'].mean():.2f}")
print(f"Max defects in single batch: {df['defect_count'].max()}")

# Defects by machine
print("\nDefects by machine:")
print(df.groupby('machine_id')['defect_count'].agg(['sum', 'mean', 'count']))

# %%
# ============================================
# YOUR CODE HERE
# Paste AI-generated code below
# ============================================

# [Your AI-generated code goes here]

# %%
# ============================================
# Validation Checks
# ============================================

# Use this cell to verify AI claims

# Example: Verify total defects
ai_claimed_total = 0  # Replace with AI's claim
actual_total = df['defect_count'].sum()
print(f"AI claimed: {ai_claimed_total}")
print(f"Actual: {actual_total}")
print(f"Match: {ai_claimed_total == actual_total}")

# %% [markdown]
# # Cheat Sheet A: Common Code Snippets for AI-Generated Analysis

# %% [markdown]
# ## Reference: Code Patterns You May Encounter
#
# ### Loading and Basic Exploration
# ```python
# # Load data
# df = pd.read_csv('filename.csv')
#
# # Basic info
# print(df.shape)
# print(df.dtypes)
# print(df.isnull().sum())
# print(df.describe())
# ```
#
# ### Grouping and Aggregation
# ```python
# # Group by single column
# df.groupby('column')['value'].mean()
#
# # Group by multiple columns
# df.groupby(['col1', 'col2'])['value'].agg(['sum', 'mean', 'count'])
#
# # Pivot table
# pd.pivot_table(df, values='value', index='row', columns='col', aggfunc='mean')
# ```
#
# ### Visualization
# ```python
# # Bar chart
# plt.figure(figsize=(10, 6))
# df.groupby('category')['value'].sum().plot(kind='bar')
# plt.title('Title')
# plt.xlabel('X Label')
# plt.ylabel('Y Label')
# plt.xticks(rotation=45)
# plt.tight_layout()
# plt.show()
#
# # Histogram
# plt.figure(figsize=(10, 6))
# plt.hist(df['column'], bins=30, edgecolor='black')
# plt.title('Distribution of Column')
# plt.xlabel('Value')
# plt.ylabel('Frequency')
# plt.show()
#
# # Scatter plot
# plt.figure(figsize=(10, 6))
# plt.scatter(df['x_column'], df['y_column'], alpha=0.5)
# plt.title('X vs Y')
# plt.xlabel('X')
# plt.ylabel('Y')
# plt.show()
#
# # Heatmap
# plt.figure(figsize=(10, 8))
# corr = df.select_dtypes(include=[np.number]).corr()
# sns.heatmap(corr, annot=True, cmap='coolwarm', center=0)
# plt.title('Correlation Matrix')
# plt.tight_layout()
# plt.show()
# ```
#
# ### Statistical Tests
# ```python
# # T-test for two groups
# from scipy import stats
#
# group1 = df[df['category'] == 'A']['value']
# group2 = df[df['category'] == 'B']['value']
#
# t_stat, p_value = stats.ttest_ind(group1, group2)
# print(f"T-statistic: {t_stat:.3f}")
# print(f"P-value: {p_value:.4f}")
#
# # ANOVA for multiple groups
# from scipy.stats import f_oneway
#
# groups = [df[df['category'] == cat]['value'] for cat in df['category'].unique()]
# f_stat, p_value = f_oneway(*groups)
# print(f"F-statistic: {f_stat:.3f}")
# print(f"P-value: {p_value:.4f}")
# ```
#
# ### Time Series
# ```python
# # Convert to datetime
# df['date'] = pd.to_datetime(df['date'])
#
# # Group by date
# daily = df.groupby(df['date'].dt.date)['value'].sum()
#
# # Moving average
# df['ma_7'] = df['value'].rolling(window=7).mean()
#
# # Plot time series
# plt.figure(figsize=(14, 6))
# plt.plot(daily.index, daily.values)
# plt.title('Daily Values Over Time')
# plt.xlabel('Date')
# plt.ylabel('Value')
# plt.xticks(rotation=45)
# plt.tight_layout()
# plt.show()

# %% [markdown]
# # Cheat Sheet B: Validation

# %% [markdown]
# ### Validating Counts and Totals
# ```python
# # AI claims: "There are X rows in the data"
# actual_rows = len(df)
#
# # AI claims: "Total defects = X"
# actual_total = df['defect_count'].sum()
#
# # AI claims: "There are X unique machines"
# actual_machines = df['machine_id'].nunique()
# ```
#
# ### Validating Averages
# ```python
# # AI claims: "Average defects per batch = X"
# actual_mean = df['defect_count'].mean()
#
# # AI claims: "Machine M7 average = X"
# m7_mean = df[df['machine_id'] == 'M7']['defect_count'].mean()
# ```
#
# ### Validating Percentages
# ```python
# # AI claims: "Night shift has X% of all defects"
# night_defects = df[df['shift'] == 'Night']['defect_count'].sum()
# total_defects = df['defect_count'].sum()
# night_pct = (night_defects / total_defects) * 100
#
# # AI claims: "Machine M7 is X% higher than average"
# m7_mean = df[df['machine_id'] == 'M7']['defect_count'].mean()
# overall_mean = df['defect_count'].mean()
# pct_higher = ((m7_mean - overall_mean) / overall_mean) * 100
# ```
#
# ### Validating Rankings
# ```python
# # AI claims: "Top 3 machines by defects are M7, M3, M9"
# actual_ranking = df.groupby('machine_id')['defect_count'].sum().sort_values(ascending=False)
# print(actual_ranking.head(3))
# ```
#
# ### Validating Statistical Claims
# ```python
# from scipy import stats
#
# # AI claims: "Night shift defects are significantly higher"
# night = df[df['shift'] == 'Night']['defect_count']
# other = df[df['shift'] != 'Night']['defect_count']
#
# t_stat, p_value = stats.ttest_ind(night, other)
# print(f"p-value: {p_value:.4f}")
# print(f"Significant at 0.05? {p_value < 0.05}")
# ```
#
# ### Validating Correlations
# ```python
# # AI claims: "Temperature is correlated with defects (r = X)"
# actual_corr = df['temperature'].corr(df['defect_count'])
# print(f"Actual correlation: {actual_corr:.3f}")
# ```
